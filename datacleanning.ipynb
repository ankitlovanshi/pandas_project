# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px

# %%
amzn = pd.read_csv('/home/developer/Downloads/AMZN.csv')

# %%
amzn
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1997-05-15    0.121875    0.125000    0.096354    0.097917    0.097917
# 1     1997-05-16    0.098438    0.098958    0.085417    0.086458    0.086458
# 2     1997-05-19    0.088021    0.088542    0.081250    0.085417    0.085417
# 3     1997-05-20    0.086458    0.087500    0.081771    0.081771    0.081771
# 4     1997-05-21    0.081771    0.082292    0.068750    0.071354    0.071354
# ...          ...         ...         ...         ...         ...         ...
# 6511  2023-03-30  101.550003  103.040001  101.010002  102.000000  102.000000
# 6512  2023-03-31  102.160004  103.489998  101.949997  103.290001  103.290001
# 6513  2023-04-03  102.300003  103.290001  101.430000  102.410004  102.410004
# 6514  2023-04-04  102.750000  104.199997  102.110001  103.949997  103.949997
# 6515  2023-04-05  103.910004  103.910004  100.750000  101.099998  101.099998
#
#           Volume
# 0     1443120000
# ...

# %%
amzn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6516 entries, 0 to 6515
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       6516 non-null   object
#  1   Open       6516 non-null   float64
#  2   High       6516 non-null   float64
#  3   Low        6516 non-null   float64
#  4   Close      6516 non-null   float64
#  5   Adj Close  6516 non-null   float64
#  6   Volume     6516 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 356.5+ KB

# %%
amzn.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
amzn.boxplot(column='Volume')
# Out:
# <Axes: >

# %%
amzn[amzn['Volume'] > 200000000]
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1997-05-15    0.121875    0.125000    0.096354    0.097917    0.097917
# 1     1997-05-16    0.098438    0.098958    0.085417    0.086458    0.086458
# 4     1997-05-21    0.081771    0.082292    0.068750    0.071354    0.071354
# 5     1997-05-22    0.071875    0.072396    0.065625    0.069792    0.069792
# 6     1997-05-23    0.070313    0.076042    0.066667    0.075000    0.075000
# ...          ...         ...         ...         ...         ...         ...
# 5767  2020-04-16  117.300003  123.050003  116.750000  120.409500  120.409500
# 6222  2022-02-03  141.737503  144.247498  138.332993  138.845505  138.845505
# 6223  2022-02-04  155.606506  161.199997  150.608002  157.639496  157.639496
# 6281  2022-04-29  129.848999  130.761002  121.625000  124.281502  124.281502
# 6407  2022-10-28   97.910004  103.959999   97.660004  103.410004  103.410004
#
#           Volume
# 0     1443120000
# ...

# %%
outliers = amzn[amzn['Volume'] > 200000000].index
amzn.drop(outliers, inplace=True)

# %%
amzn
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 2     1997-05-19    0.088021    0.088542    0.081250    0.085417    0.085417
# 3     1997-05-20    0.086458    0.087500    0.081771    0.081771    0.081771
# 7     1997-05-27    0.075521    0.082292    0.072917    0.079167    0.079167
# 8     1997-05-28    0.081250    0.081771    0.076563    0.076563    0.076563
# 9     1997-05-29    0.077083    0.077083    0.073958    0.075260    0.075260
# ...          ...         ...         ...         ...         ...         ...
# 6511  2023-03-30  101.550003  103.040001  101.010002  102.000000  102.000000
# 6512  2023-03-31  102.160004  103.489998  101.949997  103.290001  103.290001
# 6513  2023-04-03  102.300003  103.290001  101.430000  102.410004  102.410004
# 6514  2023-04-04  102.750000  104.199997  102.110001  103.949997  103.949997
# 6515  2023-04-05  103.910004  103.910004  100.750000  101.099998  101.099998
#
#          Volume
# 2     122136000
# ...

# %%
amzn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5478 entries, 2 to 6515
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5478 non-null   object
#  1   Open       5478 non-null   float64
#  2   High       5478 non-null   float64
#  3   Low        5478 non-null   float64
#  4   Close      5478 non-null   float64
#  5   Adj Close  5478 non-null   float64
#  6   Volume     5478 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 342.4+ KB

# %%
df = pd.read_csv('/home/developer/Downloads/data.csv')

# %%
df
# Out:
#                        Country  AveragScore  SafetySecurity  PersonelFreedom  \
# 0                      Denmark        84.55           92.59            94.09
# 1                       Sweden        83.67           90.97            91.90
# 2                       Norway        83.59           93.30            94.10
# 3                      Finland        83.47           89.56            91.96
# 4                  Switzerland        83.42           95.66            87.50
# ..                         ...          ...             ...              ...
# 162                    Somalia        34.39           31.91            34.32
# 163                Afghanistan        34.18           20.93            31.02
# 164   Central African Republic        32.83           35.30            36.83
# 165                      Yemen        32.65           22.60            25.30
# 166                South Sudan        30.40           16.54            26.98
#
# ...

# %%
sns.boxplot(column='AveragScore')
# Out:
# <Axes: >

# %%
def totalSum(*num):
    return sum(num)

res = totalSum(1, 2, 3, 4, 5)
print(res)
# Out:
# 15

# %%
def totalSum(*num):
    for i in num:
         print(i)

totalSum(1, 2, 3, 4, 5)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def details(**std):
    for key, value in std.items():
         print(f"{key} : {value}")

details(name='ankit', age=23, city='Indore')
# Out:
# name : ankit
# age : 23
# city : Indore
