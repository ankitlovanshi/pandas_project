# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px

# %%
amzn = pd.read_csv('/home/developer/Downloads/AMZN.csv')

# %%
amzn
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1997-05-15    0.121875    0.125000    0.096354    0.097917    0.097917
# 1     1997-05-16    0.098438    0.098958    0.085417    0.086458    0.086458
# 2     1997-05-19    0.088021    0.088542    0.081250    0.085417    0.085417
# 3     1997-05-20    0.086458    0.087500    0.081771    0.081771    0.081771
# 4     1997-05-21    0.081771    0.082292    0.068750    0.071354    0.071354
# ...          ...         ...         ...         ...         ...         ...
# 6511  2023-03-30  101.550003  103.040001  101.010002  102.000000  102.000000
# 6512  2023-03-31  102.160004  103.489998  101.949997  103.290001  103.290001
# 6513  2023-04-03  102.300003  103.290001  101.430000  102.410004  102.410004
# 6514  2023-04-04  102.750000  104.199997  102.110001  103.949997  103.949997
# 6515  2023-04-05  103.910004  103.910004  100.750000  101.099998  101.099998
#
#           Volume
# 0     1443120000
# 1      294000000
# 2      122136000
# 3      109344000
# 4      377064000
# ...          ...
# 6511    53633400
# 6512    56704300
# 6513    41135700
# 6514    48662500
# 6515    45103000
#
# [6516 rows x 7 columns]

# %%
amzn.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
amzn['Date'] = pd.to_datetime(amzn['Date'])

# %%
# set_index
amzn.set_index('Date', inplace=True)

# %%
amzn
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1997-05-15    0.121875    0.125000    0.096354    0.097917    0.097917
# 1997-05-16    0.098438    0.098958    0.085417    0.086458    0.086458
# 1997-05-19    0.088021    0.088542    0.081250    0.085417    0.085417
# 1997-05-20    0.086458    0.087500    0.081771    0.081771    0.081771
# 1997-05-21    0.081771    0.082292    0.068750    0.071354    0.071354
# ...                ...         ...         ...         ...         ...
# 2023-03-30  101.550003  103.040001  101.010002  102.000000  102.000000
# 2023-03-31  102.160004  103.489998  101.949997  103.290001  103.290001
# 2023-04-03  102.300003  103.290001  101.430000  102.410004  102.410004
# 2023-04-04  102.750000  104.199997  102.110001  103.949997  103.949997
# 2023-04-05  103.910004  103.910004  100.750000  101.099998  101.099998
#
#                 Volume
# Date
# 1997-05-15  1443120000
# 1997-05-16   294000000
# 1997-05-19   122136000
# 1997-05-20   109344000
# 1997-05-21   377064000
# ...                ...
# 2023-03-30    53633400
# 2023-03-31    56704300
# 2023-04-03    41135700
# 2023-04-04    48662500
# 2023-04-05    45103000
#
# [6516 rows x 6 columns]

# %%
# Data Analysis and Visualization

# %%
# How can I visualize the stock's closing prices over time?
sns.lineplot(amzn, x='Date', y='Close')
# Out:
# <Axes: xlabel='Date', ylabel='Close'>

# %%
# How do I calculate and plot moving averages to identify trends?
# amzn['axis_y']=amzn['Open'].mean()
# sns.lineplot(amzn, x='Date', y='axis_y')

# %%
# How can I visualize and analyze trading volume trends?
sns.lineplot(amzn, x='Date', y='Volume')
# Out:
# <Axes: xlabel='Date', ylabel='Volume'>

# %%
amzn['Volume_MA_30'] = amzn['Volume'].rolling(window=30).mean()
sns.lineplot(amzn, x='Date', y='Volume_MA_30')
# Out:
# <Axes: xlabel='Date', ylabel='Volume_MA_30'>

# %%
amzn
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1997-05-15    0.121875    0.125000    0.096354    0.097917    0.097917
# 1997-05-16    0.098438    0.098958    0.085417    0.086458    0.086458
# 1997-05-19    0.088021    0.088542    0.081250    0.085417    0.085417
# 1997-05-20    0.086458    0.087500    0.081771    0.081771    0.081771
# 1997-05-21    0.081771    0.082292    0.068750    0.071354    0.071354
# ...                ...         ...         ...         ...         ...
# 2023-03-30  101.550003  103.040001  101.010002  102.000000  102.000000
# 2023-03-31  102.160004  103.489998  101.949997  103.290001  103.290001
# 2023-04-03  102.300003  103.290001  101.430000  102.410004  102.410004
# 2023-04-04  102.750000  104.199997  102.110001  103.949997  103.949997
# 2023-04-05  103.910004  103.910004  100.750000  101.099998  101.099998
#
#                 Volume  Volume_MA_30
# Date
# 1997-05-15  1443120000           NaN
# 1997-05-16   294000000           NaN
# 1997-05-19   122136000           NaN
# 1997-05-20   109344000           NaN
# 1997-05-21   377064000           NaN
# ...                ...           ...
# 2023-03-30    53633400  5.738841e+07
# 2023-03-31    56704300  5.740058e+07
# 2023-04-03    41135700  5.677079e+07
# 2023-04-04    48662500  5.650686e+07
# 2023-04-05    45103000  5.602582e+07
#
# [6516 rows x 7 columns]

# %%
# What are the correlations between different stock features, and how can I visualize them?
orrelation_matrix = amzn[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']].corr()
sns.heatmap(orrelation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
# Out:
# <Axes: >

# %%
# How can I calculate and plot daily returns to analyze stock volatility?
amzn['Daily Return'] = amzn['Close'].pct_change()

# %%
sns.histplot(amzn['Daily Return'])

# %%
# How can I use interactive visualization libraries to create dynamic and interactive charts?
fig = px.line(amzn, x='Date', y='Close')
fig.show()

# %%
# Calculate 30-day moving average of 'Close' price
amzn['Close_MA_30'] = amzn['Close'].rolling(window=30).mean()

# Plot the 'Close' price and 30-day moving average
plt.figure(figsize=(14, 7))
sns.lineplot(x=amzn['Date'], y=amzn['Close'], label='Close')
sns.lineplot(x=amzn['Date'], y=amzn['Close_MA_30'], label='30-Day MA')
plt.title('Amazon Close Prices and 30-Day Moving Average')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
# Calculate correlation matrix
correlation_matrix = amzn[['Close', 'Volume', 'Close_MA_30']].corr()
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix')
plt.show()

# %%
# How do I document my analysis, visualizations, and insights effectively?

# jupyter nbconvert --to html your_notebook.ipynb


# by this command we can make the html file of our visulization

# %%
amzn["Year"] = pd.to_datetime(amzn['Date']).dt.year
df=amzn.groupby('Year')['Volume'].sum().reset_index()
df
# Out:
#     Year        Volume
# 0   1997   14077008000
# 1   1998  104519592000
# 2   1999   85570324000
# 3   2000   44140152000
# 4   2001   42191456000
# 5   2002   42228182000
# 6   2003   45557118000
# 7   2004   42884632000
# 8   2005   36109708000
# 9   2006   35822042000
# 10  2007   48954882000
# 11  2008   50384174000
# 12  2009   42916886000
# 13  2010   36739730000
# 14  2011   29199572000
# 15  2012   20998082000
# 16  2013   14958114000
# 17  2014   20581334000
# 18  2015   19142040000
# 19  2016   20775126000
# 20  2017   17654108000
# 21  2018   28357952000
# 22  2019   19493002000
# 23  2020   24950814000
# 24  2021   17076362000
# 25  2022   19096256300
# 26  2023    4371724800

# %%
sns.barplot(df, x='Year', y='Volume')
plt.xticks(rotation=90)
plt.xlabel('Year')
plt.ylabel('Total Volume')
plt.show()

# %%
sns.histplot(df['Volume'])
# Out:
# <Axes: xlabel='Volume', ylabel='Count'>
